# %%
import warnings

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import missingno as msno

import funciones_auxiliares_hito_2 as aux2

sns.set_theme()
plt.rcParams['figure.figsize'] = (12, 6)
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('students.csv', sep='|').drop(columns='Unnamed: 0')
df = df.replace(['nulidade', 'sem validade', 'zero'], np.nan)
df = aux2.corregir_variables_numericas(df)

# %% [markdown]
# # Analisis del vector objetivo (```G1```, ```G2``` o ```G3```)

# %%
g1 = df['G1']
g2 = df['G2']
g3 = df['G3']

# %%
aux2.analizar_vector_objetivo_discreto(g1)
aux2.analizar_vector_objetivo_discreto(g2)
aux2.analizar_vector_objetivo_discreto(g3)
# Out:
#       Frecuencia  Porcentaje
# 10.0          50    0.127877
# 8.0           41    0.104859
# 11.0          38    0.097187
# 7.0           36    0.092072
# 12.0          35    0.089514
# 13.0          33    0.084399
# 9.0           31    0.079284
# 14.0          30    0.076726
# 15.0          24    0.061381
# 6.0           23    0.058824
# 16.0          22    0.056266
# 18.0           8    0.020460
# 17.0           8    0.020460
# 5.0            7    0.017903
# 19.0           3    0.007673
# 4.0            1    0.002558
# 3.0            1    0.002558
# La variable presentó 4 valores faltantes
#       Frecuencia  Porcentaje
# 9.0           50    0.126582
# 10.0          46    0.116456
# 12.0          41    0.103797
# 13.0          37    0.093671
# 11.0          35    0.088608
# 15.0          34    0.086076
# 8.0           32    0.081013
# 14.0          23    0.058228
# 7.0           21    0.053165
# 5.0           15    0.037975
# 6.0           14    0.035443
# ...

# %% [markdown]
# # Analisis de resultados
#
# - G1: Se pudo ver que existen 17 notas distintas. La nota que obtuvo la mayor frecuencia fue
# un 10, y la que obtuvo la menor frecuencia fue un 3. Esta variable presentó 4 valores faltantes
#
# - G2: Se pudo ver que existen 17 notas distintas. La nota que obtuvo la mayor frecuencia fue un 0, y la que obtuvo la menor frecuencia fue un 4. Esta variable presentó 0 valores faltantes
#
# - G3: Se pudo ver que existen 18 notas distintas. La nota que obtuvo la mayor frecuencia fue un 10, y la que obtuvo la menor frecuencia fue un 4. Esta variable presentó 3 valores faltantes

# %% [markdown]
# # Analisis de variables independientes (todas menos ```G1```, ```G2``` o ```G3```)

# %%
variables_independientes = df.drop(columns=['G1', 'G2', 'G3'])
aux2.analizar_variables_indpendientes(variables_independientes)
# Out:
# Analizando todas las variables numericas
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  391.000000  392.000000  390.000000  392.000000  390.000000  390.000000
# mean    16.698210    2.742347    2.525641    1.451531    2.038462    0.335897
# std      1.279412    1.095185    1.088906    0.699066    0.842970    0.746883
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.500000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  390.000000  393.000000  390.000000  392.000000  390.000000  391.000000
# ...

# %% [markdown]
# # Analisis variables numéricas
#
# - ```age``` : Tiene una media de 16.7 años. Según el gráfico de cajas y bigotes presenta 1 valor atípico. Presenta 4 valores faltantes
# - ```Medu```: Tiene una media de 2.74. El 75% de los datos se agrupa entre 2.0 y 4.0. No presenta
# valores atípicos. Presenta 3 valores faltantes.
# - ```Fedu```: Tiene una media de 2.52. El 50% de los datos se agrupa entre 2.0 y 3.0 Presenta 1 valor
# atípico. Tiene 5 valores faltantes.
# - ```traveltime```: Tiene una media de 1.45. El 75% de los datos se agrupa entre 1 y 3. Presenta 1
# valor atípico. Tiene 3 valores faltantes.
# - ```studytime```: Tiene una media de 2.04. El 75% de los datos se agrupa entre 1 y 3. Presenta 1
# valor atípico. Tiene 5 valores faltantes.
# - ```failures```: Tiene una media de 0.34. Casi el 100% de los datos están cerca de 0, y presenta
# 3 datos atípicos. Tiene 5 valores faltantes.
# - ```famrel```: Tiene una media de 3.94. Casi el 75% de los datos están entre 3 y 5. Presenta 2 datos
# atípicos. Tiene 5 valors faltantes.
# - ```freetime```: Tiene una media de 3.23. Casi el 50% de los datos están entre 3 y 4. Presenta 1 dato
# atípicos. Tiene 2 valors faltantes.
# - ```goout```: Tiene una media de 3.10. Casi el 50% de los datos están entre 2 y 3. No presenta datos
# atípicos. Tiene 5 valors faltantes.
# - ```Dalc```: Tiene una media de 1.48. Casi el 100% de los datos están entre 1 y 3. Presenta 2 datos
# atípicos. Tiene 3 valors faltantes.
# - ```Walc```: Tiene una media de 2.29. Casi el 75% de los datos están entre 1 y 3. No presenta datos
# atípicos. Tiene 5 valors faltantes.
# - ```health```: Tiene una media de 3.57. Casi el 75% de los datos están entre 3 y 5. No presenta datos
# atípicos. Tiene 4 valors faltantes.
# - ```absences```: Tiene una media de 5.73. Casi el 100% de los datos están entre 0 y 20. Presenta datos
# atípicos. Tiene 4 valors faltantes.
#
# # Analisis variables categoricas
#
# ## Binarias
#
# - ```school```: Presento 345 de GP y 45 de MS. Tuvo 5 valores faltantes.
# - ```sex```: Presento 206 de F y 186 de M. Tuvo 3 valores faltantes.
# - ```address```: Presento 305 de U y 88 de R. Tuvo 2 valores faltantes.
# - ```famsize```: Presento 278 de GT3 y 113 de LE3. Tuvo 4 valores faltantes.
# - ```Pstatus```: Presento 349 de T y 40 de A. Tuvo 6 valores faltantes.
# - ```schoolsup```: Presento 337 de no y 50 de yes. Tuvo 8 valores faltantes.
# - ```famsup```: Presento 239 de yes y 151 de no. Tuvo 5 valores faltantes.
# - ```paid```: Presento 214 de no y 180 de yes. Tuvo 1 valor faltante.
# - ```activities```: Presento 199 de yes y 191 de no. Tuvo 5 valores faltantes.
# - ```nursery```: Presento 309 de yes y 80 de no. Tuvo 6 valores faltantes.
# - ```higher```: Presento 369 de yes y 20 de no. Tuvo 6 valores faltantes.
# - ```internet```: Presento 327 de yes y 65 de no. Tuvo 3 valores faltantes.
# - ```romantic```: Presento 262 de no y 131 de yes. Tuvo 2 valores faltantes.
#
# ## No Binarias
#
# - ```Mjob```: El valor other fue el que tuvo la mayor frecuencia, con 138 conteos. El valor health
# fue el que tuvo la menor frecuencia, con 33 conteos. Tuvo 6 valores faltantes.
# - ```Fjob```: El valor other fue el que tuvo la mayor frecuencia, con 217 conteos. El valor health
# fue el que tuvo la menor frecuencia, con 18 conteos. Tuvo 0 valores faltantes.
# - ```reason```: El valor course fue el que tuvo la mayor frecuencia, con 144 conteos. El valor other
# fue el que tuvo la menor frecuencia, con 36 conteos. Tuvo 4 valores faltantes.
# - ```guardian```: El valor mother fue el que tuvo la mayor frecuencia, con 270 conteos. El valor
# other fue el que tuvo la menor frecuencia, con 32 conteos. Tuvo 4 valores faltantes.

# %% [markdown]
# # Analisis valores faltantes global

# %%
aux2.mostrar_perdida_de_datos(df)
# Out:
# Al droppear todos los valores faltantes en la DataFrame se pierde el 28.1% de los datos totales

# %% [markdown]
# Como se pierde menos del 30% de los datos totales, entonces se procede a tratar los datos
# con un .dropna() global

# %% [markdown]
# # Analizar correlacion entre variables disponibles

# %%
aux2.analizar_correlacion_todas_las_variables(df)

# %% [markdown]
# De forma general se puede ver que la variables presentan una correlacion baja-moderada (< 0.2).
# Sin embargo, las variables G1 - G2 y G3 presentan una alta correlacion (> 0.8). Asi mismo, las variables
# Dalc y Walc presentan una correlacion moderada-alta entre si.

# %% [markdown]
# # Preprocesamiento y Recodificacion
#
# Como se menciono en el Hito 1, y teniendo en cuenta los resultados del analisis exploratorio
# de las variables, los datos seran preprocesados y recodificados de la siguiente manera:
#
# 1. Se reemplazarán todos los valores 'nulidade', 'sem validade', 'zero' con np.nan
# 2. Se eliminarán todas las filas que tengan un valor faltante
# 3. Se eliminará la columna ```Unnamed: 0```
# 4. Se corregiran las variables numericas que presenten el caracter '"' (comillas dobles), y las
# que sean leidas erroneamente por la funcion pd.read_csv().
# 5. Se recodificaran las variables mencionadas en el enunciado como se estipula. O sea, todas las
# variables categoricas binarias seran codificadas a 0s y 1s, segun la frecuencia de sus valores
# (el valor con la menor frecuencia ira con 0, y el con mayor frecuencia con 1).
# 6. Todas las variables categoricas no binarias seran codificadas segun el metodo Leave-One-Out
# Encoding.

# %%
df = pd.read_csv('students.csv', sep='|')
df_final = aux2.preprocesar_y_recodificar_enunciado_dos(df)
