# %%
import warnings

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import missingno as msno

import funciones_auxiliares_hito_2 as aux2

sns.set_theme()
plt.rcParams['figure.figsize'] = (12, 6)

# %%
df = pd.read_csv('students.csv', sep='|', encoding='latin-1')
df = df.replace(['nulidade', 'sem validade', 'zero'], np.nan)
df = aux2.cambiar_vars_numericas_en_string(df)

# %% [markdown]
# # Analisis del vector objetivo (```G1```, ```G2``` o ```G3```)

# %%
g1 = df['G1']
g2 = df['G2']
g3 = df['G3']

# %%
df.describe()
# Out:
#        Unnamed: 0         age       goout      health          G2
# count  395.000000  391.000000  390.000000  391.000000  395.000000
# mean   197.000000   16.698210    3.102564    3.570332   10.713924
# std    114.170924    1.279412    1.117629    1.377303    3.761505
# min      0.000000   15.000000    1.000000    1.000000    0.000000
# 25%     98.500000   16.000000    2.000000    3.000000    9.000000
# 50%    197.000000   17.000000    3.000000    4.000000   11.000000
# 75%    295.500000   18.000000    4.000000    5.000000   13.000000
# max    394.000000   22.000000    5.000000    5.000000   19.000000

# %%
aux2.analizar_vector_objetivo_discreto(g1)
aux2.analizar_vector_objetivo_discreto(g2)
aux2.analizar_vector_objetivo_discreto(g3)
# Out:
#     Frecuencia  Porcentaje
# 10          50    0.127877
# 8           41    0.104859
# 11          38    0.097187
# 7           36    0.092072
# 12          35    0.089514
# 13          33    0.084399
# 9           31    0.079284
# 14          30    0.076726
# 15          24    0.061381
# 6           23    0.058824
# 16          22    0.056266
# 18           8    0.020460
# 17           8    0.020460
# 5            7    0.017903
# 19           3    0.007673
# 4            1    0.002558
# 3            1    0.002558
#     Frecuencia  Porcentaje
# 9           50    0.126582
# 10          46    0.116456
# 12          41    0.103797
# 13          37    0.093671
# 11          35    0.088608
# 15          34    0.086076
# 8           32    0.081013
# 14          23    0.058228
# 7           21    0.053165
# 5           15    0.037975
# 6           14    0.035443
# 16          13    0.032911
# 0           13    0.032911
# 18          12    0.030380
# 17           5    0.012658
# 19           3    0.007595
# 4            1    0.002532
#     Frecuencia  Porcentaje
# 10          55    0.140306
# 11          47    0.119898
# 0           37    0.094388
# 15          33    0.084184
# 8           32    0.081633
# 13          31    0.079082
# 12          31    0.079082
# 9           27    0.068878
# 14          27    0.068878
# 16          16    0.040816
# 6           15    0.038265
# 18          12    0.030612
# 7            9    0.022959
# 5            7    0.017857
# 17           6    0.015306
# 19           5    0.012755
# 20           1    0.002551
# 4            1    0.002551

# %% [markdown]
# # Analisis de variables independientes (todas menos ```G1```, ```G2``` o ```G3```)

# %%
variables_independientes = df.drop(columns=['G1', 'G2', 'G3'])
aux2.analizar_variables_indpendientes(variables_independientes)
# Out:
# Analizando todas las variables numericas
#        Unnamed: 0         age       goout      health
# count  395.000000  391.000000  390.000000  391.000000
# mean   197.000000   16.698210    3.102564    3.570332
# std    114.170924    1.279412    1.117629    1.377303
# min      0.000000   15.000000    1.000000    1.000000
# 25%     98.500000   16.000000    2.000000    3.000000
# 50%    197.000000   17.000000    3.000000    4.000000
# 75%    295.500000   18.000000    4.000000    5.000000
# max    394.000000   22.000000    5.000000    5.000000
# Analizando todas las variables categoricas
#
# school
# GP    345
# MS     45
# Name: school, dtype: int64
# sex
# F    206
# M    186
# Name: sex, dtype: int64
# address
# U    305
# R     88
# Name: address, dtype: int64
# famsize
# GT3    278
# LE3    113
# Name: famsize, dtype: int64
# Pstatus
# T    349
# A     40
# Name: Pstatus, dtype: int64
# Medu
# 4    129
# 2    103
# 3     98
# 1     59
# 0      3
# Name: Medu, dtype: int64
# Fedu
# 2    112
# 3    100
# 4     95
# 1     81
# 0      2
# Name: Fedu, dtype: int64
# Mjob
# other       138
# services    102
# at_home      59
# teacher      57
# health       33
# Name: Mjob, dtype: int64
# Fjob
# other       217
# services    111
# teacher      29
# at_home      20
# health       18
# Name: Fjob, dtype: int64
# reason
# course        144
# home          108
# reputation    103
# other          36
# Name: reason, dtype: int64
# guardian
# mother    270
# father     89
# other      32
# Name: guardian, dtype: int64
# traveltime
# 1    254
# 2    107
# 3     23
# 4      8
# Name: traveltime, dtype: int64
# studytime
# 2    194
# 1    104
# 3     65
# 4     27
# Name: studytime, dtype: int64
# failures
# 0    308
# 1     49
# 2     17
# 3     16
# Name: failures, dtype: int64
# schoolsup
# no     337
# yes     50
# Name: schoolsup, dtype: int64
# famsup
# yes    239
# no     151
# Name: famsup, dtype: int64
# paid
# no     214
# yes    180
# Name: paid, dtype: int64
# activities
# yes    199
# no     191
# Name: activities, dtype: int64
# nursery
# yes    309
# no      80
# Name: nursery, dtype: int64
# higher
# yes    369
# no      20
# Name: higher, dtype: int64
# internet
# yes    327
# no      65
# Name: internet, dtype: int64
# romantic
# no     262
# yes    131
# Name: romantic, dtype: int64
# famrel
# 4    194
# 5    105
# 3     65
# 2     18
# 1      8
# Name: famrel, dtype: int64
# freetime
# 3    157
# 4    114
# 2     64
# 5     39
# 1     19
# Name: freetime, dtype: int64
# Dalc
# 1    274
# 2     74
# 3     26
# 5      9
# 4      9
# Name: Dalc, dtype: int64
# Walc
# 1    150
# 2     82
# 3     79
# 4     51
# 5     28
# Name: Walc, dtype: int64
# absences
# 0     113
# 2      64
# 4      53
# 6      31
# 8      22
# 10     17
# 14     12
# 12     11
# 3       8
# 16      7
# 7       7
# 5       5
# 18      5
# 20      4
# 11      3
# 9       3
# 13      3
# 15      3
# 22      3
# 1       3
# 38      1
# 30      1
# 40      1
# 23      1
# 19      1
# 28      1
# 75      1
# 21      1
# 24      1
# 56      1
# 26      1
# 54      1
# 25      1
# 17      1
# Name: absences, dtype: int64
#                columna  cantidad_na  porcentaje_na
# Unnamed: 0  Unnamed: 0            0           0.00
# school          school            5           1.27
# sex                sex            3           0.76
# age                age            4           1.01
# address        address            2           0.51
# famsize        famsize            4           1.01
# Pstatus        Pstatus            6           1.52
# Medu              Medu            3           0.76
# Fedu              Fedu            5           1.27
# Mjob              Mjob            6           1.52
# Fjob              Fjob            0           0.00
# reason          reason            4           1.01
# guardian      guardian            4           1.01
# traveltime  traveltime            3           0.76
# studytime    studytime            5           1.27
# failures      failures            5           1.27
# schoolsup    schoolsup            8           2.03
# famsup          famsup            5           1.27
# paid              paid            1           0.25
# activities  activities            5           1.27
# nursery        nursery            6           1.52
# higher          higher            6           1.52
# internet      internet            3           0.76
# romantic      romantic            2           0.51
# famrel          famrel            5           1.27
# freetime      freetime            2           0.51
# goout            goout            5           1.27
# Dalc              Dalc            3           0.76
# Walc              Walc            5           1.27
# health          health            4           1.01
# absences      absences            4           1.01

# %% [markdown]
# # Analisis valores faltantes global

# %%
aux2.mostrar_perdida_de_datos(df)
# Out:
# Al droppear todos los valores faltantes en la DataFrame se pierde el 28.1% de los datos totales

# %%
# Analizar correlacion entre variables disponibles

# %%
aux2.analizar_correlacion_todas_las_variables(df)
