# %% [markdown]
# # Variables aleatorios e histogramas
#
# Los histogramas permiten ver la distribución de variables continuas. En el eje x van los valors que hay en el espacio de muestra, mientras que en el eje y va la frecuencia de cada uno de los datos.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('subsample_isz.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5736/2763107971.py in <module>
# ----> 1 df = pd.read_csv('subsample_isz.csv', index_col=True)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df
# Out:
#     Unnamed: 0                       cname ccodealp    ht_region    gle_cgdpc  \
# 0            0                      Tuvalu      TUV      Pacific   3174.05000
# 1            1                     Liberia      LBR  SubSaharian    488.26999
# 2            2                        Togo      TGO  SubSaharian   1036.28000
# 3            3                        Peru      PER        LatAm   9227.15040
# 4            4       Sao Tome and Principe      STP  SubSaharian   2150.55000
# ..         ...                         ...      ...          ...          ...
# 92          92                      Guinea      GIN  SubSaharian    993.83002
# 93          93                     Belarus      BLR   EastEurope  17780.64100
# 94          94                 El Salvador      SLV        LatAm    332.26999
# 95          95               Cote d'Ivoire      CIV  SubSaharian   1354.29000
# 96          96  Congo, Democratic Republic      COD  SubSaharian    324.16000
#
# ...
