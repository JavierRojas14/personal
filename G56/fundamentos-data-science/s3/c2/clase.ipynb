# %% [markdown]
# # Clase 2
#
# No se que fue lo que vieron la clase pasada, pero weno. Era mi cumpleaños asi que amo.
#
# # Joins
#
# Estamos viendo los joins, wowzies!. Estamos haciendo INNER JOINS!
#
# - INNER JOIN: Solamente queda lo que esté en ambas tablas
# - LEFT JOIN: Queda todo lo de la tabla de la izquierda, y junta solo lo que tiene la tabla de la derecha
# - OUTER JOIN: Junta ambas tablas completamente

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('qog_std_cs_jan18.csv')
df_2 = pd.read_csv('subsample_isz.csv')

# %%
df_clase = df[['cname', 'ccode', 'undp_hdi', 'ht_region']]

# %%
df_2
# Out:
#     Unnamed: 0                       cname ccodealp    ht_region    gle_cgdpc  \
# 0            0                      Tuvalu      TUV      Pacific   3174.05000
# 1            1                     Liberia      LBR  SubSaharian    488.26999
# 2            2                        Togo      TGO  SubSaharian   1036.28000
# 3            3                        Peru      PER        LatAm   9227.15040
# 4            4       Sao Tome and Principe      STP  SubSaharian   2150.55000
# ..         ...                         ...      ...          ...          ...
# 92          92                      Guinea      GIN  SubSaharian    993.83002
# 93          93                     Belarus      BLR   EastEurope  17780.64100
# 94          94                 El Salvador      SLV        LatAm    332.26999
# 95          95               Cote d'Ivoire      CIV  SubSaharian   1354.29000
# 96          96  Congo, Democratic Republic      COD  SubSaharian    324.16000
#
# ...

# %% [markdown]
# # Variables aleatorias
#
# - Son funciones que asignan un valor numérico a un resultado de un experimento aleatorio
# - Permiten asignar un valor numéricos al espacio muestral (o sea, en vez de decir 'cara', podemos asociarlo al número 0 y 'sello' a 1)
#
#
# # Variables aleatorias Continuas
#
# ## Distribución Normal
#
# - Es de las distribuciones más comunes y deseadas
# - Presenta característica que facilitan la inferencia estadística
# - Depende de la media y varianza
#
# # Simular una distribución normal
#
# ```python
# np.random.normal(loc=media, scale=np.sqrt(varianza), size=1000)
# ```
#
# # Plottear un histograma
#
# ```python
# import matplotlib.pyplot as plt
#
# plt.hist(x, y, density=True)
# ```
#
# ## Plottear la curva normal sobre los datos
#
# ```python
#
# from scipy.stats import norm
#
# # El x debe abarcar todo el eje X
# # pdf es Probability Density Function
#
# x_axis = np.linspace(0, 1.5, 1000)
# y_axis = norm.pdf(x_axis, media, np.sqrt(varianza))
# plt.plot(x_axis, y_axis)
# ```

# %%
import lec3_graphs as gfx

# %%
gfx.normal_distributions()

# %% [markdown]
# # Función acumulada
#
# Es la suma de la probabilidad a lo largo del rango. Primero se suma poca probabilidad, luego
# se pega un salto (ya que se suma el rango de la media del centro) y luego suma poco de nuevo (porque
# llega d enuevo a la cola)
