# %% [markdown]
# ### Prueba 2 - Hito 2 - Javier Rojas Benitez - G56

# %%
import importlib

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings

import funciones_auxiliares_hito_1 as aux1
import funciones_auxiliares_hito_2 as aux2

warnings.filterwarnings("ignore")
sns.set_style()
plt.rcParams["figure.figsize"] = (12, 6)

importlib.reload(aux1)
importlib.reload(aux2)
# Out:
# <module 'funciones_auxiliares_hito_2' from 'c:\\Users\\ppizarro\\Desktop\\Javier Rojas\\Javier\\propio\\personal\\G56\\machine-learning\\prueba\\prueba_2\\hito_2\\funciones_auxiliares_hito_2.py'>

# %%
df = pd.read_csv("input/2009_1perc.csv").drop(columns="Unnamed: 0")
df = aux2.preprocesar_vectores_objetivos(df)
# Out:
# ['perobs']

# %% [markdown]
# # Analisis Exploratorio

# %% [markdown]
# ## Variables dependientes - ```arstmade``` y ```violent```

# %% [markdown]
# - En el hito 1 se abordo todo el analisis exploratorio de los vectores objetivos (```arstmade``` y ```violent```). Debido a lo anterior,
# se obviara esta seccion en el cuadernillo.

# %% [markdown]
# ## Variables Independientes

# %% [markdown]
# - Cabe destacar que cada problema tendra su set de variables independientes. Debido a lo anterior,
# se utilizaran dos dataframes distintos para la resolucion de cada problema.
#
# - En el Problema 1 (Prediccion de Arresto), la variable dependiente sera ```arstmade```, y las
# variables independientes corresponderan a todas las demas variables.
#
# - En el Problema 2 (Prediccion de Detencion Violenta), la variable dependiente sera ```violent```,
# y las variables independientes corresponderan a todas las demas variables. Ademas, se eliminaran
# todas las variables utilizadas para crear la variable ```violent```. Por lo tanto, se eliminaran
# las variables ```pf_hands```, ```pf_wall```, ```pf_grnd```, ```pf_drwep```, ```pf_ptwep```, ```pf_baton```, ```pf_hcuff```, ```pf_pepsp```, ```pf_other```.

# %%
vars_independientes_totales = df.drop(columns=["arstmade", "violent"])
aux1.analizar_distribucion_y_faltantes_variables(vars_independientes_totales)
# Out:
# Analizando todas las variables numericas
#              month       meters
# count  4636.000000  4636.000000
# mean      6.994823     1.720899
# std       3.320684     0.113465
# min       1.000000     0.914400
# 25%       4.000000     1.615440
# 50%       7.000000     1.737360
# 75%      10.000000     1.798320
# max      12.000000     2.167128
# -----------------------------------------
# -----------------------------------------
# -----------------------------------------
# -----------------------------------------
# Analizando todas las variables categoricas
#
# -----------------------------------------
#    Frecuencia  Porcentaje
# A        2923      0.6305
# 1        1713      0.3695
# -----------------------------------------
# -----------------------------------------
#    Frecuencia  Porcentaje
# O        3480    0.750647
# I        1156    0.249353
# -----------------------------------------
# -----------------------------------------
#    Frecuencia  Porcentaje
# ...

# %%
y_n = vars_independientes_totales.isin(["Y", "N"]).sum(axis=0)
contienen_y_n = y_n[y_n > 0]
display(contienen_y_n.to_frame())
print(len(contienen_y_n))
# Out:
#              0
# explnstp  4636
# othpers   4636
# sumissue  4636
# offunif   4636
# officrid  4636
# frisked   4636
# searched  4636
# contrabn  4636
# pistol    4636
# riflshot  4636
# asltweap  4636
# knifcuti  4636
# othrweap  4636
# pf_hands  4636
# pf_wall   4636
# pf_grnd   4636
# pf_drwep  4636
# pf_ptwep  4636
# pf_baton  4636
# pf_hcuff  4636
# pf_pepsp  4636
# pf_other  4636
# radio     4636
# ac_rept   4636
# ac_inves  4636
# rf_vcrim  4636
# rf_othsw  4636
# ac_proxm  4636
# rf_attir  4636
# cs_objcs  4636
# cs_descr  4636
# cs_casng  4636
# cs_lkout  4636
# rf_vcact  4636
# cs_cloth  4636
# cs_drgtr  4636
# ac_evasv  4636
# ac_assoc  4636
# cs_furtv  4636
# rf_rfcmp  4636
# ac_cgdir  4636
# rf_verbl  4636
# cs_vcrim  4636
# cs_bulge  4636
# cs_other  4636
# ac_incid  4636
# ac_time   4636
# rf_knowl  4636
# ac_stsnd  4636
# ac_other  4636
# sb_hdobj  4636
# sb_outln  4636
# sb_admis  4636
# sb_other  4636
# rf_furt   4636
# rf_bulg   4636
# offverb   4636
# ...

# %% [markdown]
# - Debido a la gran cantidad de variables independientes disponibles, se obviara el analisis
# especifico de cada una. Sin embargo, de forma general se observan los siguientes resultados:
#
#     - Los datos presentan 2 variables numericas
#     - Existen 58 variables categoricas binarias que poseen una codificacion "Y" y "N". Estas
#     variables seran recodificadas segun el diccionario mencionado en el hito 1. La variable
#     ```sector``` contiene el valor "N", por lo tanto se debe recodificar el valor de esta variable
#     previo a modificar todo el dataframe con el diccionario mencionado en el hito 1. El valor "N"
#     sera modificado con el valor "Z".
#     - Las variables independientes carecen de valores faltantes

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Variables dependientes - ```arstmade``` y ```violent```

# %% [markdown]
# - En el hito 1 se abordo todo el preprocesamiento de los vectores objetivos (```arstmade``` y ```violent```). Debido a lo anterior,
# se obviara esta seccion en el cuadernillo.

# %% [markdown]
# ## Variables Independientes
#
# - Se reemplazara el valor "N" de la variable ```sector``` por el valor "Z"
# - Se reemplazaran todos los valores "Y" por 1, y todos los valores "N" por 0
# - Se codificaran todas las variables categoricas con el metodo de Leave One Out Hot Encoding

# %%
df["sector"] = df["sector"].replace({"N": "Z"})
df = df.replace({"Y": 1, "N": 0})

# %% [markdown]
# ### Problema 1 - Prediccion de Arresto

# %%
X_problema_1_train = df.drop(columns=["arstmade"])
X_problema_1_train = aux2.unir_codificacion_one_hot_vars_categoricas(X_problema_1_train)

y_problema_1_train = df["arstmade"]

# %% [markdown]
# ### Problema 2 - Detencion Violenta

# %%
X_problema_2_train = df.drop(
    columns=[
        "violent",
        "pf_hands",
        "pf_wall",
        "pf_grnd",
        "pf_drwep",
        "pf_ptwep",
        "pf_baton",
        "pf_hcuff",
        "pf_pepsp",
        "pf_other",
    ]
)
X_problema_2_train = aux2.unir_codificacion_one_hot_vars_categoricas(X_problema_2_train)

y_problema_2_train = df["violent"]

# %% [markdown]
# - Todo el preprocesamiento (variables dependientes e independientes) sera modularizado en una unica funcion

# %%
def preprocesar_vectores_independientes_prueba_2_machine_learning(df):
    df["sector"] = df["sector"].replace({"N": "Z"})
    df = df.replace({"Y": 1, "N": 0})

    X_problema_1 = df.drop(columns=["arstmade"])
    X_problema_1 = aux2.unir_codificacion_one_hot_vars_categoricas(X_problema_1)

    y_problema_1 = df["arstmade"]

    df_problema_1 = pd.concat([X_problema_1, y_problema_1], axis=1)

    X_problema_2 = df.drop(
        columns=[
            "violent",
            "pf_hands",
            "pf_wall",
            "pf_grnd",
            "pf_drwep",
            "pf_ptwep",
            "pf_baton",
            "pf_hcuff",
            "pf_pepsp",
            "pf_other",
        ]
    )

    X_problema_2 = aux2.unir_codificacion_one_hot_vars_categoricas(X_problema_2)

    y_problema_2 = df["violent"]

    df_problema_2 = pd.concat([X_problema_2, y_problema_2], axis=1)

    return df_problema_1, df_problema_2


def preprocesar_todo_prueba_2_machine_learning(ruta_archivo):
    df = pd.read_csv(ruta_archivo).drop(columns="Unnamed: 0")

    df_final = aux2.preprocesar_vectores_objetivos(df)
    df_problema_1, df_problema_2 = preprocesar_vectores_independientes_prueba_2_machine_learning(df_final)

    return df_problema_1, df_problema_2

# %% [markdown]
# # Modelacion

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ### Problema 1 - Prediccion de Arresto

# %%
grilla_logistic_problema_1 = {
    "C": [0.0001, 0.001, 0.01, 0.1, 1, 10],
    "solver": ["newton-cg", "lbfgs", "liblinear", "sag", "saga"],
}

grilla_naive_bayes_problema_1 = {
    "alpha": [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000],
    "fit_prior": [True, False],
}


grilla_gradient_boosting_problema_1 = {
    "max_depth": range(5, 11),
    "learning_rate": [0.001, 0.01, 0.1, 1],
}


modelo_logistic_problema_1 = GridSearchCV(
    LogisticRegression(),
    grilla_logistic_problema_1,
    cv=5,
    scoring="accuracy",
    n_jobs=-1,
)


modelo_naive_bayes_problema_1 = GridSearchCV(
    MultinomialNB(), grilla_naive_bayes_problema_1, cv=5, scoring="accuracy", n_jobs=-1
)

modelo_gradient_boosting_problema_1 = GridSearchCV(
    GradientBoostingClassifier(),
    grilla_gradient_boosting_problema_1,
    cv=5,
    scoring="accuracy",
    n_jobs=-1,
)

# %% [markdown]
# ### Problema 2 - Detencion Violenta

# %%
grilla_logistic_problema_2 = {
    "C": [0.0001, 0.001, 0.01, 0.1, 1, 10],
    "solver": ["newton-cg", "lbfgs", "liblinear", "sag", "saga"],
}

grilla_naive_bayes_problema_2 = {
    "alpha": [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000],
    "fit_prior": [True, False],
}

grilla_gradient_boosting_problema_2 = {
    "max_depth": range(5, 11),
    "learning_rate": [0.001, 0.01, 0.1, 1],
}

grilla_arbol_clasificacion_problema_2 = {
    "max_depth": range(3, 11),
    "max_leaf_nodes": range(1, 6),
    "criterion": ["gini", "entropy"],
}

grilla_random_forest_problema_2 = {
    "max_depth": range(5, 11),
    "n_estimators": range(500, 1001, 100),
    "max_features": ["sqrt", "log2"],
}


modelo_logistic_problema_2 = GridSearchCV(
    LogisticRegression(),
    grilla_logistic_problema_2,
    cv=5,
    scoring="accuracy",
    n_jobs=-1,
)

modelo_naive_bayes_problema_2 = GridSearchCV(
    MultinomialNB(), grilla_naive_bayes_problema_2, cv=5, scoring="accuracy", n_jobs=-1
)

modelo_gradient_boosting_problema_2 = GridSearchCV(
    GradientBoostingClassifier(),
    grilla_gradient_boosting_problema_2,
    cv=5,
    scoring="accuracy",
    n_jobs=-1,
)

modelo_arbol_problema_2 = GridSearchCV(
    DecisionTreeClassifier(),
    grilla_arbol_clasificacion_problema_2,
    cv=5,
    scoring="accuracy",
    n_jobs=-1,
)

modelo_random_forest_problema_2 = GridSearchCV(
    RandomForestClassifier(), grilla_random_forest_problema_2, cv=5, scoring="accuracy", n_jobs=-1
)

# %% [markdown]
# # Division de Muestra

# %% [markdown]
# - Previamente [ya se separaron los datos en variables independientes y vectores objetivos para
# cada problema](#preprocesamiento). Debido a lo anterior, este apartado se centrara en cargar
# los datos de validacion.

# %%
df_val = pd.read_csv("input/2010_1perc.csv").drop(columns="Unnamed: 0")
df_final_val = aux2.preprocesar_vectores_objetivos(df)
df_final_val["sector"] = df_final_val["sector"].replace({"N": "Z"})
df_final_val = df_final_val.replace({"Y": 1, "N": 0})

X_problema_1_test = df_final_val.drop(columns=["arstmade"])
X_problema_1_test = aux2.unir_codificacion_one_hot_vars_categoricas(X_problema_1_test)

y_problema_1_test = df_final_val["arstmade"]

X_problema_2_test = df_final_val.drop(
    columns=[
        "violent",
        "pf_hands",
        "pf_wall",
        "pf_grnd",
        "pf_drwep",
        "pf_ptwep",
        "pf_baton",
        "pf_hcuff",
        "pf_pepsp",
        "pf_other",
    ]
)
X_problema_2_test = aux2.unir_codificacion_one_hot_vars_categoricas(X_problema_2_test)

y_problema_2_test = df_final_val["violent"]
# Out:
# ['perobs', 'meters', 'age_individual']

# %% [markdown]
# # Entrenamiento de los modelos

# %% [markdown]
# ### Problema 1 - Prediccion de Arresto

# %%
modelo_logistic_problema_1.fit(X_problema_1_train, y_problema_1_train)
resultados_logistic_problema_1 = aux2.obtener_desempeno_modelo_en_grilla(
    modelo_logistic_problema_1, X_problema_1_test, y_problema_1_test
)
# Out:
# --------------Resultados Conjunto de Entrenamiento-----------------
# Los resultados en la busqueda de hiperparametros son:
# Los mejores parametros fueron: {'C': 10, 'solver': 'saga'}
# El mejor desempeno fue: 0.9674292303686345
#
#
# --------------Resultados Conjunto de Validacion-----------------
# Los resultados en el conjunto de validacion son:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      4355
#            1       0.90      0.65      0.75       281
#
#     accuracy                           0.97      4636
#    macro avg       0.94      0.82      0.87      4636
# weighted avg       0.97      0.97      0.97      4636
#
# El ROC fue de: 0.8232117539867049
# ---------------------------------------------------------------------

# %%
modelo_naive_bayes_problema_1.fit(X_problema_1_train, y_problema_1_train)
resultados_naive_bayes_problema_1 = aux2.obtener_desempeno_modelo_en_grilla(
    modelo_naive_bayes_problema_1, X_problema_1_test, y_problema_1_test
)
# Out:
# --------------Resultados Conjunto de Entrenamiento-----------------
# Los resultados en la busqueda de hiperparametros son:
# Los mejores parametros fueron: {'alpha': 0.1, 'fit_prior': True}
# El mejor desempeno fue: 0.95987961723022
#
#
# --------------Resultados Conjunto de Validacion-----------------
# Los resultados en el conjunto de validacion son:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98      4355
#            1       0.64      0.74      0.69       281
#
#     accuracy                           0.96      4636
#    macro avg       0.81      0.86      0.83      4636
# weighted avg       0.96      0.96      0.96      4636
#
# El ROC fue de: 0.8585680957381174
# ---------------------------------------------------------------------

# %%
modelo_gradient_boosting_problema_1.fit(X_problema_1_train, y_problema_1_train)
resultados_gradient_boosting_problema_1 = aux2.obtener_desempeno_modelo_en_grilla(
    modelo_gradient_boosting_problema_1, X_problema_1_test, y_problema_1_test
)
# Out:
# --------------Resultados Conjunto de Entrenamiento-----------------
# Los resultados en la busqueda de hiperparametros son:
# Los mejores parametros fueron: {'learning_rate': 0.1, 'max_depth': 8}
# El mejor desempeno fue: 0.9667822136666295
#
#
# --------------Resultados Conjunto de Validacion-----------------
# Los resultados en el conjunto de validacion son:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4355
#            1       0.98      0.93      0.95       281
#
#     accuracy                           0.99      4636
#    macro avg       0.99      0.96      0.97      4636
# weighted avg       0.99      0.99      0.99      4636
#
# El ROC fue de: 0.9637239480124697
# ---------------------------------------------------------------------

# %% [markdown]
# ### Problema 2 - Detencion Violenta

# %%
modelo_logistic_problema_2.fit(X_problema_2_train, y_problema_2_train)
resultados_logistic_problema_2 = aux2.obtener_desempeno_modelo_en_grilla(
    modelo_logistic_problema_2, X_problema_2_test, y_problema_2_test
)
# Out:
# --------------Resultados Conjunto de Entrenamiento-----------------
# Los resultados en la busqueda de hiperparametros son:
# Los mejores parametros fueron: {'C': 0.01, 'solver': 'newton-cg'}
# El mejor desempeno fue: 0.7657481028903025
#
#
# --------------Resultados Conjunto de Validacion-----------------
# Los resultados en el conjunto de validacion son:
#               precision    recall  f1-score   support
#
#            0       0.78      0.97      0.87      3500
#            1       0.64      0.16      0.26      1136
#
#     accuracy                           0.77      4636
#    macro avg       0.71      0.57      0.56      4636
# weighted avg       0.75      0.77      0.72      4636
#
# El ROC fue de: 0.566117203219316
# ---------------------------------------------------------------------

# %%
modelo_naive_bayes_problema_2.fit(X_problema_2_train, y_problema_2_train)
resultados_naive_bayes_problema_2 = aux2.obtener_desempeno_modelo_en_grilla(
    modelo_naive_bayes_problema_2, X_problema_2_test, y_problema_2_test
)
# Out:
# --------------Resultados Conjunto de Entrenamiento-----------------
# Los resultados en la busqueda de hiperparametros son:
# Los mejores parametros fueron: {'alpha': 10, 'fit_prior': True}
# El mejor desempeno fue: 0.762295177249563
#
#
# --------------Resultados Conjunto de Validacion-----------------
# Los resultados en el conjunto de validacion son:
#               precision    recall  f1-score   support
#
#            0       0.80      0.91      0.85      3500
#            1       0.53      0.31      0.39      1136
#
#     accuracy                           0.76      4636
#    macro avg       0.67      0.61      0.62      4636
# weighted avg       0.74      0.76      0.74      4636
#
# El ROC fue de: 0.6115588531187122
# ---------------------------------------------------------------------

# %%
modelo_gradient_boosting_problema_2.fit(X_problema_2_train, y_problema_2_train)
resultados_gradient_boosting_problema_2 = aux2.obtener_desempeno_modelo_en_grilla(
    modelo_gradient_boosting_problema_2, X_problema_2_test, y_problema_2_test
)
# Out:
# --------------Resultados Conjunto de Entrenamiento-----------------
# Los resultados en la busqueda de hiperparametros son:
# Los mejores parametros fueron: {'learning_rate': 0.1, 'max_depth': 5}
# El mejor desempeno fue: 0.7642341349551761
#
#
# --------------Resultados Conjunto de Validacion-----------------
# Los resultados en el conjunto de validacion son:
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92      3500
#            1       0.92      0.50      0.65      1136
#
#     accuracy                           0.87      4636
#    macro avg       0.89      0.74      0.78      4636
# weighted avg       0.87      0.87      0.85      4636
#
# El ROC fue de: 0.7415251509054326
# ---------------------------------------------------------------------

# %%
modelo_arbol_problema_2.fit(X_problema_2_train, y_problema_2_train)
resultados_arbol_problema_2 = aux2.obtener_desempeno_modelo_en_grilla(
    modelo_arbol_problema_2, X_problema_2_test, y_problema_2_test
)
# Out:
# --------------Resultados Conjunto de Entrenamiento-----------------
# Los resultados en la busqueda de hiperparametros son:
# Los mejores parametros fueron: {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 4}
# El mejor desempeno fue: 0.7560384350704906
#
#
# --------------Resultados Conjunto de Validacion-----------------
# Los resultados en el conjunto de validacion son:
#               precision    recall  f1-score   support
#
#            0       0.78      0.95      0.86      3500
#            1       0.52      0.17      0.26      1136
#
#     accuracy                           0.76      4636
#    macro avg       0.65      0.56      0.56      4636
# weighted avg       0.72      0.76      0.71      4636
#
# El ROC fue de: 0.5614336016096579
# ---------------------------------------------------------------------

# %%
modelo_random_forest_problema_2.fit(X_problema_2_train, y_problema_2_train)
resultados_random_forest_problema_2 = aux2.obtener_desempeno_modelo_en_grilla(
    modelo_random_forest_problema_2, X_problema_2_test, y_problema_2_test
)
# Out:
# --------------Resultados Conjunto de Entrenamiento-----------------
# Los resultados en la busqueda de hiperparametros son:
# Los mejores parametros fueron: {'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 600}
# El mejor desempeno fue: 0.7670419038053788
#
#
# --------------Resultados Conjunto de Validacion-----------------
# Los resultados en el conjunto de validacion son:
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89      3500
#            1       1.00      0.23      0.37      1136
#
#     accuracy                           0.81      4636
#    macro avg       0.90      0.62      0.63      4636
# weighted avg       0.85      0.81      0.76      4636
#
# El ROC fue de: 0.6151740442655936
# ---------------------------------------------------------------------

# %% [markdown]
# # Exportacion de modelos entrenados

# %%
import pickle

diccionario_exportacion = {
    "modelo_logistic_problema_1.pickle": modelo_logistic_problema_1,
    "modelo_naive_bayes_problema_1.pickle": modelo_naive_bayes_problema_1,
    "modelo_gradient_boosting_problema_1.pickle": modelo_gradient_boosting_problema_1,
    "modelo_logistic_problema_2.pickle": modelo_logistic_problema_2,
    "modelo_naive_bayes_problema_2.pickle": modelo_naive_bayes_problema_2,
    "modelo_gradient_boosting_problema_2.pickle": modelo_gradient_boosting_problema_2,
    "modelo_arbol_problema_2.pickle": modelo_arbol_problema_2,
    "modelo_random_forest_problema_2.pickle": modelo_random_forest_problema_2,
}

for nombre_archivo, modelo in diccionario_exportacion.items():
    with open(nombre_archivo, "wb") as file:
        pickle.dump(modelo, file)
